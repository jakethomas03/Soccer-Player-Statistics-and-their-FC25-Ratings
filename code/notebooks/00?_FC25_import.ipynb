# %% [markdown]
# # FC25 Data Import Notebook
# **Author:** Jake Thomas
# **Last Modified:** 11/20/2024 (created: 11/20/2024)
#
# **Description:** Downloading the FC25 Dataset into a pandas dataframe.

# %%
# import libraries
import pandas as pd

# %%
fc25_df = pd.read_csv("/Users/Jake/Documents/GitHub/Data-Wrangling-Project/data/raw/FC25 Dataset/male_players.csv")
display(fc25_df)
# Out:
#        Unnamed: 0.1  Unnamed: 0   Rank             Name  OVR  PAC  SHO  PAS  \
# 0                 0           0      1    Kylian Mbappé   91   97   90   80
# 1                 1           1      2            Rodri   91   66   80   86
# 2                 2           2      4   Erling Haaland   91   88   92   70
# 3                 3           3      5  Jude Bellingham   90   80   87   83
# 4                 4           4      7         Vini Jr.   90   95   84   81
# ...             ...         ...    ...              ...  ...  ...  ...  ...
# 16156         16156       16156  17717     Engson Singh   47   31   45   47
# 16157         16157       16157  17717    Ousmane Sylla   47   67   38   46
# 16158         16158       16158  17717         Wei Feng   47   57   47   38
# 16159         16159       16159  17717       Won Hui Do   47   66   35   46
# 16160         16160       16160  17717        Wu Yuhang   47   56   34   43
#
# ...
